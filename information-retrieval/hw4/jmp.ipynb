# %%
import random

# %%
array = sorted([random.randint(0, 100000) for _ in range(1000)])

# %%
array
# Out:
# [23,
#  73,
#  481,
#  489,
#  535,
#  702,
#  888,
#  1041,
#  1331,
#  1466,
#  1577,
#  1608,
#  1678,
#  1702,
#  1755,
#  1852,
#  2081,
#  2160,
#  2252,
#  2321,
#  2465,
#  2493,
#  2645,
#  2852,
#  2881,
#  2894,
#  3134,
#  3141,
#  3143,
#  3188,
#  3225,
#  3251,
#  3268,
#  3401,
#  3502,
#  3524,
#  3663,
#  3738,
#  3790,
#  3913,
#  4479,
#  4486,
#  4519,
#  4580,
#  4603,
#  4840,
#  4931,
#  5037,
#  5058,
#  5134,
#  5167,
#  5235,
#  5236,
#  5516,
#  5522,
#  5558,
#  5631,
#  5687,
#  5844,
#  5928,
#  6084,
#  6115,
#  6137,
#  6181,
#  6207,
#  6253,
#  6349,
#  6372,
#  6500,
#  6685,
#  6836,
#  7039,
#  7076,
#  7254,
#  7281,
#  7687,
#  7715,
#  7774,
#  7829,
#  8161,
#  8276,
#  8292,
#  8477,
#  8581,
#  8589,
#  8781,
#  8797,
#  8903,
#  8957,
#  9209,
#  9231,
#  9300,
#  9393,
#  9396,
#  9413,
#  9725,
#  9775,
#  9789,
#  9844,
#  9954,
#  9966,
#  9975,
#  9982,
#  10062,
#  10142,
#  10199,
#  10204,
#  10290,
#  10302,
#  10497,
#  10682,
# ...

# %%
def read_from(start, end):
    return iter(array[start:end])

# %%
list(read_from(40, 40))
# Out:
# []

# %%
import itertools
gen = itertools.izip(itertools.count(0), iter(array[::100]))

# %%
def find_value(value, jmp)

# %%
# find value in index
#    = find value in jmp
#   read and compare value from index

# %%
def find_in_iter(iterator, lookfor):
    for i, value in iterator:
        if lookfor < value:
            return (itertools.chain([(i, value)], iterator), i)

# %%
gen, i = find_in_iter(gen, 100)
print i
# Out:
# 1

# %%
t = 10000
for i, v in enumerate(jmp):
    if t < v:
        print i - 1
        break
# Out:
# 1

# %%
print array[1*100:2*100]
# Out:
# [9966, 9975, 9982, 10062, 10142, 10199, 10204, 10290, 10302, 10497, 10682, 10706, 10719, 10735, 10749, 10866, 10902, 11074, 11274, 11285, 11298, 11303, 11345, 11368, 11511, 11642, 11814, 11841, 11936, 12024, 12147, 12379, 12396, 12525, 12610, 12731, 12738, 12774, 12812, 13022, 13078, 13081, 13278, 13302, 13477, 13505, 13562, 13982, 14226, 14599, 14678, 14889, 15012, 15065, 15180, 15572, 15794, 16357, 16374, 16650, 16826, 16973, 17232, 17326, 17396, 17491, 17862, 18032, 18116, 18388, 18406, 18461, 18498, 18530, 18552, 18692, 18766, 18767, 18896, 18953, 19054, 19199, 19230, 19369, 19447, 19467, 19593, 19672, 19692, 19855, 19930, 19944, 20093, 20309, 20456, 20580, 20582, 20603, 20722, 20728]

# %%
def gen_gen(a):
    for v in a:
        yield v

# %%
gen_gen(jmp)
# Out:
# <generator object gen_gen at 0x1057abd20>

# %%
import itertools

gen = iter([1,2,3])
peek = gen.next()
itertools.chain([peek], gen)
# Out:
# [1, 2, 3]
